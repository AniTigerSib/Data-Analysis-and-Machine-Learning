# %% [markdown]
# # 1. Примеры типов данных

# %%
#Строковые (str)
x = "Hello World"
#вывод переменной
x
# Out:
# 'Hello World'

# %%
#Целочисленные (int)
x = 5
#вывод переменной
x
# Out:
# 5

# %%
#С точкой (float)
x = 36.6
#вывод переменной
x
# Out:
# 36.6

# %%
#Списки (list)
x = ["яблоки", "бананы", "апельсины"]
#вывод переменной
x
# Out:
# ['яблоки', 'бананы', 'апельсины']

# %%
#обращение к элементу списка
x[0]
# Out:
# 'яблоки'

# %%
#словари (dict)
x = {"name":"Evgeny", "age":33}
#вывод переменной
x
# Out:
# {'name': 'Evgeny', 'age': 33}

# %%
#можно получить конкретное значение по имени поля
x["name"]
# Out:
# 'Evgeny'

# %%
#или так
x.get("name")
# Out:
# 'Evgeny'

# %%
#булевы (bool)
x = True
#вывод переменной
x
# Out:
# True

# %% [markdown]
# # 2. Работа с Pandas

# %% [markdown]
# Pandas — это библиотека Python, предназначенная для быстрой загрузки и операций в первую очередь с т.н. панельными данными (многмерные временые ряды).
#
# Но помимо этого она используется аналитиками и просто в качестве "Excel на стероидах".
#
# Основнное достинство библиотеки - простая работа с файлами в форматах .csv,  .tsv или .xls

# %% [markdown]
# Основными структурами данных в Pandas являются классы Series и DataFrame.
#
# Первый из них представляет собой одномерный индексированный массив данных некоторого фиксированного типа.
#
# Второй - это двухмерная структура данных, представляющая собой таблицу, каждый столбец которой содержит данные одного типа.

# %% [markdown]
# ## 2.1 Основные методы в Pandas

# %%
# импорт библиотек
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2.1.1 Чтение данных

# %% [markdown]
# Часто, в проектах по анализу данных используют выгруженные из внешних источников данные, которые представлены в формате csv.
# В случае английской локализации, эти файлы отличаются тем, что:
# 1)	Разделитель – запятая, а не точа запятой
# 2)	Разделитель числа – точка а не запятая
# 3)	Формат кодировки – UTF-8
#
# Давайте  попробуем загрузить файл marketing_eng.csv в нашу систему.

# %%
df = pd.read_csv('../resources/lab1_3/marketing_eng.csv')

# %% [markdown]
# В данном случае, мы загружаем содержимое файла scoring_eng.csv в переменную df.
# Поскольку по умолчанию Jupyter настроен на работу с именно английской локалью, нам нет необходимости использовать
# дополнительные аргументы для метода.

# %% [markdown]
# Давайте посмотрим, что же загрузилось в переменную?
#
# Для этого напишем в следующем блоке название переменной – df.head
#
# Данная команда возвращает первые 5 записей

# %%
df.head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
# 1       0   32                  1                  0       1
# 2       0   52                  1                  0       1
# 3       0   39                  1                  0       1
# 4       0   30                  1                  0       0
#
#              EDUCATION  MARITAL_STATUS                    ORG_TP_STATE  \
# 0  Среднее специальное  Состою в браке                Частная компания
# 1              Среднее  Состою в браке  Индивидуальный предприниматель
# 2     Неполное среднее  Состою в браке    Государственная комп./учреж.
# 3               Высшее  Состою в браке    Государственная комп./учреж.
# 4              Среднее  Состою в браке    Государственная комп./учреж.
#
#                          JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0    Вспомогательный техперсонал           5000.0         0       18.0
# 1  Участие в основ. деятельности          12000.0         0       97.0
# 2  Участие в основ. деятельности           9000.0         0       84.0
# 3  Участие в основ. деятельности          25000.0         0      168.0
# 4  Участие в основ. деятельности          12000.0         0      101.0
#
#    LOAN_MAX_DLQ_AMT
# 0            1580.0
# 1            4020.0
# 2               0.0
# 3            1590.0
# 4            2230.0

# %% [markdown]
# В данном случае, мы загружаем содержимое файла scoring_eng.csv в переменную data.
# Поскольку по умолчанию Jupyter настроен на работу с именно английской локалью, нам нет необходимости использовать дополнительные аргументы для метода.

# %% [markdown]
# ### 2.1.2 Загрузка данных в русской локали

# %% [markdown]
# Ключевые отличия российской локализации csv файлов заключаются в:
# 1)	Разделитель – точка запятой
# 2)	Разделитель числа – запятая
# 3)	Формат кодировки – чаще всего - ANSI

# %% [markdown]
# Давайте посмотрим, что получится если нничего не менять в свойствах метода

# %%
df = pd.read_csv('../resources/lab1_3/marketing_rus.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv('../resources/lab1_3/marketing_rus.csv')
#
# File ~/Desktop/university/DAandML/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/university/DAandML/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/university/DAandML/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/university/DAandML/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/Desktop/university/DAandML/.venv/lib/python3.13/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd1 in position 164: invalid continuation byte

# %% [markdown]
# Для того чтобы загрузить русские версии файлов необходимо задать соответствующие параметры загрузки:
#
# Аргументы:
# Sep – задает формат разделителя колонок
# Encoding – кодировку
# Decimal – десятичный разделитель разрядов

# %%
df = pd.read_csv('../resources/lab1_3/marketing_rus.csv', sep=';', encoding='cp1251', decimal=',')

# %% [markdown]
# ### 2.1.3 Загрузка Excel  в русской локализации

# %%
excel = pd.read_excel('../resources/lab1_3/marketing.xls', sheet_name=0)

# %% [markdown]
# ## 2.2 Операции с данными

# %% [markdown]
# ### 2.2.1 Посмотрим на размер данных, названия признаков и их типы

# %%
print(df.shape)
# Out:
# (15223, 13)

# %% [markdown]
# Видим, что в таблице 15 223 pfgbcb и 13 колонок (переменных). Выведем названия столбцов:

# %%
print(df.columns)
# Out:
# Index(['TARGET', 'AGE', 'SOCSTATUS_WORK_FL', 'SOCSTATUS_PENS_FL', 'GENDER',
#        'EDUCATION', 'MARITAL_STATUS', 'ORG_TP_STATE', 'JOB_DIR',
#        'PERSONAL_INCOME', 'OWN_AUTO', 'WORK_TIME', 'LOAN_MAX_DLQ_AMT'],
#       dtype='object')

# %% [markdown]
# Чтобы узнать информацию по DataFrame и всем признакам (тип данных и т.п.), используют info:

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15223 entries, 0 to 15222
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TARGET             15223 non-null  int64
#  1   AGE                15223 non-null  int64
#  2   SOCSTATUS_WORK_FL  15223 non-null  int64
#  3   SOCSTATUS_PENS_FL  15223 non-null  int64
#  4   GENDER             15223 non-null  int64
#  5   EDUCATION          15223 non-null  object
#  6   MARITAL_STATUS     15223 non-null  object
#  7   ORG_TP_STATE       13856 non-null  object
#  8   JOB_DIR            13856 non-null  object
#  9   PERSONAL_INCOME    15223 non-null  float64
#  10  OWN_AUTO           15223 non-null  int64
#  11  WORK_TIME          13855 non-null  float64
#  12  LOAN_MAX_DLQ_AMT   15223 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.5+ MB
# None

# %%
df.head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
# 1       0   32                  1                  0       1
# 2       0   52                  1                  0       1
# 3       0   39                  1                  0       1
# 4       0   30                  1                  0       0
#
#              EDUCATION  MARITAL_STATUS                    ORG_TP_STATE  \
# 0  Среднее специальное  Состою в браке                Частная компания
# 1              Среднее  Состою в браке  Индивидуальный предприниматель
# 2     Неполное среднее  Состою в браке    Государственная комп./учреж.
# 3               Высшее  Состою в браке    Государственная комп./учреж.
# 4              Среднее  Состою в браке    Государственная комп./учреж.
#
#                          JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0    Вспомогательный техперсонал           5000.0         0       18.0
# 1  Участие в основ. деятельности          12000.0         0       97.0
# 2  Участие в основ. деятельности           9000.0         0       84.0
# 3  Участие в основ. деятельности          25000.0         0      168.0
# 4  Участие в основ. деятельности          12000.0         0      101.0
#
#    LOAN_MAX_DLQ_AMT
# 0            1580.0
# 1            4020.0
# 2               0.0
# 3            1590.0
# 4            2230.0

# %% [markdown]
# Изменить тип колонки можно с помощью метода astype. Применим этот метод к признаку AGE и переведём его в float64:

# %%
df['AGE'] = df['AGE'].astype('float64')

# %% [markdown]
# С помощью команды df.head() мы видим, что тип данных изменился

# %%
df.head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
# 1       0   32                  1                  0       1
# 2       0   52                  1                  0       1
# 3       0   39                  1                  0       1
# 4       0   30                  1                  0       0
#
#              EDUCATION  MARITAL_STATUS                    ORG_TP_STATE  \
# 0  Среднее специальное  Состою в браке                Частная компания
# 1              Среднее  Состою в браке  Индивидуальный предприниматель
# 2     Неполное среднее  Состою в браке    Государственная комп./учреж.
# 3               Высшее  Состою в браке    Государственная комп./учреж.
# 4              Среднее  Состою в браке    Государственная комп./учреж.
#
#                          JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0    Вспомогательный техперсонал           5000.0         0       18.0
# 1  Участие в основ. деятельности          12000.0         0       97.0
# 2  Участие в основ. деятельности           9000.0         0       84.0
# 3  Участие в основ. деятельности          25000.0         0      168.0
# 4  Участие в основ. деятельности          12000.0         0      101.0
#
#    LOAN_MAX_DLQ_AMT
# 0            1580.0
# 1            4020.0
# 2               0.0
# 3            1590.0
# 4            2230.0

# %% [markdown]
# #### Описательная статистика

# %% [markdown]
# Метод describe показывает основные статистические характеристики данных по каждому #числовому признаку
# (типы int64 и  float64):
#     1) число непропущенных значений,
#     2) среднее,
#     3) стандартное отклонение,
#     4) диапазон,
#     5) медиану

# %%
df.describe()
# Out:
#              TARGET           AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# count  15223.000000  15223.000000       15223.000000       15223.000000
# mean       0.119030     40.406096           0.909610           0.134468
# std        0.323835     11.601068           0.286748           0.341165
# min        0.000000     21.000000           0.000000           0.000000
# 25%        0.000000     30.000000           1.000000           0.000000
# 50%        0.000000     39.000000           1.000000           0.000000
# 75%        0.000000     50.000000           1.000000           0.000000
# max        1.000000     67.000000           1.000000           1.000000
#
#              GENDER  PERSONAL_INCOME      OWN_AUTO     WORK_TIME  \
# count  15223.000000     15223.000000  15223.000000  1.385500e+04
# mean       0.654536     13853.836323      0.116337  2.922120e+02
# std        0.475535      9015.467617      0.320844  2.436483e+04
# min        0.000000        24.000000      0.000000  1.000000e+00
# 25%        0.000000      8000.000000      0.000000  2.400000e+01
# 50%        1.000000     12000.000000      0.000000  4.800000e+01
# 75%        1.000000     17000.000000      0.000000  1.100000e+02
# max        1.000000    250000.000000      2.000000  2.867959e+06
#
#        LOAN_MAX_DLQ_AMT
# count      15223.000000
# mean         243.021626
# std          836.100116
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max        28012.200000

# %% [markdown]
# Чтобы посмотреть статистику по нечисловым признакам, нужно явно указать интересующие нас типы в параметре include.
# Можно также задать include='all', чтоб вывести статистику по всем имеющимся признакам.

# %%
df.describe(include=['object', 'bool'])
# Out:
#                   EDUCATION  MARITAL_STATUS      ORG_TP_STATE  \
# count                 15223           15223             13856
# unique                    7               5                 5
# top     Среднее специальное  Состою в браке  Частная компания
# freq                   6518            9416              6523
#
#                               JOB_DIR
# count                           13856
# unique                             10
# top     Участие в основ. деятельности
# freq                            11452

# %%
df.describe(include='all')
# Out:
#               TARGET           AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# count   15223.000000  15223.000000       15223.000000       15223.000000
# unique           NaN           NaN                NaN                NaN
# top              NaN           NaN                NaN                NaN
# freq             NaN           NaN                NaN                NaN
# mean        0.119030     40.406096           0.909610           0.134468
# std         0.323835     11.601068           0.286748           0.341165
# min         0.000000     21.000000           0.000000           0.000000
# 25%         0.000000     30.000000           1.000000           0.000000
# 50%         0.000000     39.000000           1.000000           0.000000
# 75%         0.000000     50.000000           1.000000           0.000000
# max         1.000000     67.000000           1.000000           1.000000
#
#               GENDER            EDUCATION  MARITAL_STATUS      ORG_TP_STATE  \
# count   15223.000000                15223           15223             13856
# unique           NaN                    7               5                 5
# top              NaN  Среднее специальное  Состою в браке  Частная компания
# freq             NaN                 6518            9416              6523
# mean        0.654536                  NaN             NaN               NaN
# std         0.475535                  NaN             NaN               NaN
# min         0.000000                  NaN             NaN               NaN
# 25%         0.000000                  NaN             NaN               NaN
# 50%         1.000000                  NaN             NaN               NaN
# 75%         1.000000                  NaN             NaN               NaN
# max         1.000000                  NaN             NaN               NaN
#
#                               JOB_DIR  PERSONAL_INCOME      OWN_AUTO  \
# count                           13856     15223.000000  15223.000000
# unique                             10              NaN           NaN
# top     Участие в основ. деятельности              NaN           NaN
# freq                            11452              NaN           NaN
# mean                              NaN     13853.836323      0.116337
# std                               NaN      9015.467617      0.320844
# min                               NaN        24.000000      0.000000
# 25%                               NaN      8000.000000      0.000000
# 50%                               NaN     12000.000000      0.000000
# 75%                               NaN     17000.000000      0.000000
# max                               NaN    250000.000000      2.000000
#
#            WORK_TIME  LOAN_MAX_DLQ_AMT
# count   1.385500e+04      15223.000000
# unique           NaN               NaN
# top              NaN               NaN
# freq             NaN               NaN
# mean    2.922120e+02        243.021626
# std     2.436483e+04        836.100116
# min     1.000000e+00          0.000000
# 25%     2.400000e+01          0.000000
# 50%     4.800000e+01          0.000000
# 75%     1.100000e+02          0.000000
# max     2.867959e+06      28012.200000

# %% [markdown]
# Для категориальных (тип object) и булевых (тип bool) признаков можно воспользоваться методом value_counts.
# Посмотрим на распределение нашей целевой переменной — EDUCATION:

# %%
df['EDUCATION'].value_counts()
# Out:
# Среднее специальное               6518
# Среднее                           4679
# Высшее                            3133
# Неоконченное высшее                532
# Неполное среднее                   340
# Два и более высших образования      20
# Ученая степень                       1
# Name: EDUCATION, dtype: int64

# %% [markdown]
# Укажем значение параметра normalize=True, чтобы посмотреть не абсолютные частоты, а относительные.
# Например, доли лиц с разным семейным статусом

# %%
df['MARITAL_STATUS'].value_counts(normalize=True)
# Out:
# Состою в браке        0.618538
# Не состоял в браке    0.237929
# Разведен(а)           0.081784
# Вдовец/Вдова          0.038626
# Гражданский брак      0.023123
# Name: MARITAL_STATUS, dtype: float64

# %% [markdown]
# ## 2.3 Сортировка данных

# %% [markdown]
# DataFrame можно отсортировать по значению какого-нибудь из признаков.
# В нашем случае, например, по WORK_TIME (ascending=False для сортировки по убыванию):

# %%
df.sort_values(by='WORK_TIME', ascending=False).head()
# Out:
#       TARGET   AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 8984       0  25.0                  1                  0       1
# 4296       0  50.0                  1                  0       1
# 2532       0  58.0                  1                  0       1
# 5375       0  64.0                  1                  1       1
# 9852       0  38.0                  1                  1       1
#
#                 EDUCATION      MARITAL_STATUS                  ORG_TP_STATE  \
# 8984  Среднее специальное  Не состоял в браке  Государственная комп./учреж.
# 4296              Среднее      Состою в браке  Государственная комп./учреж.
# 2532  Среднее специальное        Вдовец/Вдова              Частная компания
# 5375  Среднее специальное      Состою в браке              Частная компания
# 9852              Среднее      Состою в браке              Частная компания
#
#                             JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 8984  Участие в основ. деятельности           9000.0         0  2867959.0
# 4296  Участие в основ. деятельности          10000.0         0    10000.0
# 2532  Участие в основ. деятельности          20000.0         0     4320.0
# 5375    Вспомогательный техперсонал          18000.0         0     3500.0
# 9852  Участие в основ. деятельности           8000.0         0     1500.0
#
#       LOAN_MAX_DLQ_AMT
# 8984               0.0
# 4296               0.0
# 2532               0.0
# 5375               0.0
# 9852            2020.0

# %% [markdown]
# Сортировать можно и по группе столбцов:

# %%
df.sort_values(by=['WORK_TIME', 'PERSONAL_INCOME'], ascending=[False, False]).head()
# Out:
#       TARGET   AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 8984       0  25.0                  1                  0       1
# 4296       0  50.0                  1                  0       1
# 2532       0  58.0                  1                  0       1
# 5375       0  64.0                  1                  1       1
# 9852       0  38.0                  1                  1       1
#
#                 EDUCATION      MARITAL_STATUS                  ORG_TP_STATE  \
# 8984  Среднее специальное  Не состоял в браке  Государственная комп./учреж.
# 4296              Среднее      Состою в браке  Государственная комп./учреж.
# 2532  Среднее специальное        Вдовец/Вдова              Частная компания
# 5375  Среднее специальное      Состою в браке              Частная компания
# 9852              Среднее      Состою в браке              Частная компания
#
#                             JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 8984  Участие в основ. деятельности           9000.0         0  2867959.0
# 4296  Участие в основ. деятельности          10000.0         0    10000.0
# 2532  Участие в основ. деятельности          20000.0         0     4320.0
# 5375    Вспомогательный техперсонал          18000.0         0     3500.0
# 9852  Участие в основ. деятельности           8000.0         0     1500.0
#
#       LOAN_MAX_DLQ_AMT
# 8984               0.0
# 4296               0.0
# 2532               0.0
# 5375               0.0
# 9852            2020.0

# %% [markdown]
# ## 2.4 Индексация и извлечение данных

# %% [markdown]
# Для извлечения отдельного столбца можно использовать конструкцию вида DataFrame['Name']. Воспользуемся этим для ответа на вопрос: какова доля владельцев авто в нашем датафрейме?

# %%
df['OWN_AUTO'].mean()
# Out:
# 0.11633712146094725

# %% [markdown]
# В Pandas есть возможность управлять отбором с помощью логических условий - давайте посмотрим - каковы средние характеристики
# владельцев автомобилей?

# %%
df[df['OWN_AUTO'] == 1].mean()
# Out:
# TARGET                   0.137931
# AGE                     38.585076
# SOCSTATUS_WORK_FL        0.967213
# SOCSTATUS_PENS_FL        0.059921
# GENDER                   0.304127
# PERSONAL_INCOME      18301.039005
# OWN_AUTO                 1.000000
# WORK_TIME               80.890251
# LOAN_MAX_DLQ_AMT       284.343929
# dtype: float64

# %%
Также можно комбинировать указанные выше подходы

# %%
df[df['TARGET'] == 1]['PERSONAL_INCOME'].mean()
# Out:
# 13540.436160614421

# %% [markdown]
# ## 2.5 Группировка данных

# %% [markdown]
# В общем случае группировка данных в Pandas выглядит следующим образом:
#
# df.groupby(by=grouping_columns)[columns_to_show].function()
#    1) К датафрейму применяется метод groupby, который разделяет данные по grouping_columns – признаку или набору признаков.
#    2)  Индексируем по нужным нам столбцам (columns_to_show).
#    3)  К полученным группам применяется функция или несколько функций.

# %%
df.groupby(['TARGET'])['AGE', 'WORK_TIME', 'PERSONAL_INCOME'].agg([np.mean, np.std, np.min, np.max])
# Out:
#               AGE                         WORK_TIME                     \
#              mean        std  amin  amax       mean           std amin
# TARGET
# 0       40.849005  11.697037  21.0  67.0  325.42413  26079.479331  1.0
# 1       37.128035  10.290703  21.0  65.0   64.26958     75.522526  1.0
#
#                   PERSONAL_INCOME
#              amax            mean           std    amin      amax
# TARGET
# 0       2867959.0    13540.436161   8794.221229    24.0  250000.0
# 1           864.0    16173.378035  10217.147092  3000.0  150000.0

# %% [markdown]
# ## 2.6 Сводные таблицы

# %% [markdown]
# Допустим, мы хотим посмотреть, как наблюдения в нашей выборке распределены в контексте двух признаков — GENDER и MARITAL_STATUS.
# Для этого мы можем построить таблицу сопряженности, воспользовавшись методом crosstab:

# %%
pd.crosstab(df['GENDER'], df['EDUCATION'])
# Out:
# EDUCATION  Высшее  Два и более высших образования  Неоконченное высшее  \
# GENDER
# 0             978                              10                  186
# 1            2155                              10                  346
#
# EDUCATION  Неполное среднее  Среднее  Среднее специальное  Ученая степень
# GENDER
# 0                       133     1710                 2242               0
# 1                       207     2969                 4276               1

# %%
pd.crosstab(df['GENDER'], df['EDUCATION'], normalize=True)
# Out:
# EDUCATION    Высшее  Два и более высших образования  Неоконченное высшее  \
# GENDER
# 0          0.064245                        0.000657             0.012218
# 1          0.141562                        0.000657             0.022729
#
# EDUCATION  Неполное среднее   Среднее  Среднее специальное  Ученая степень
# GENDER
# 0                  0.008737  0.112330             0.147277        0.000000
# 1                  0.013598  0.195034             0.280891        0.000066

# %% [markdown]
# Продвинутые пользователи Excel наверняка вспомнят о такой фиче, как сводные таблицы (pivot tables).
#
# В Pandas за сводные таблицы отвечает метод pivot_table, который принимает в качестве параметров:
#
# values – список переменных, по которым требуется рассчитать нужные статистики,
#
# index – список переменных, по которым нужно сгруппировать данные,
#
# aggfunc — то, что нам, собственно, нужно посчитать по группам — сумму, среднее, максимум, минимум или что-то ещё.

# %%
df.pivot_table(['AGE','WORK_TIME','PERSONAL_INCOME'], ['OWN_AUTO', 'GENDER'], aggfunc='mean')
# Out:
#                        AGE  PERSONAL_INCOME   WORK_TIME
# OWN_AUTO GENDER
# 0        0       38.116216     16110.229739   72.451647
#          1       41.728093     12055.115339  435.543015
# 1        0       38.194963     19095.190089   76.089925
#          1       39.477695     16483.938662   92.150391
# 2        0       22.000000     15000.000000   36.000000

# %% [markdown]
# ## 2.7 Индексация

# %% [markdown]
# Датафреймы можно индексировать как по названию столбца или строки, так и по порядковому номеру.
#
# Для индексации **по названию** используется метод **loc***, по **номеру** — **iloc.**
#
# В первом случае мы говорим *«передай нам значения для id строк от 0 до 5 и для столбцов от GENDER до ORG_TP_STATE»*, а во втором — *«передай нам значения первых пяти строк в столбцах с 4 по 7 (не вкдючая 7)»*.
#
# В случае iloc срез работает как обычно, однако в случае loc учитываются и начало, и конец среза. Да, неудобно, да, вызывает путаницу.

# %%
df.loc[0:5, 'GENDER':'ORG_TP_STATE']
# Out:
#    GENDER            EDUCATION    MARITAL_STATUS  \
# 0       1  Среднее специальное    Состою в браке
# 1       1              Среднее    Состою в браке
# 2       1     Неполное среднее    Состою в браке
# 3       1               Высшее    Состою в браке
# 4       0              Среднее    Состою в браке
# 5       0              Среднее  Гражданский брак
#
#                      ORG_TP_STATE
# 0                Частная компания
# 1  Индивидуальный предприниматель
# 2    Государственная комп./учреж.
# 3    Государственная комп./учреж.
# 4    Государственная комп./учреж.
# 5                Частная компания

# %%
df.iloc[0:5, 4:7]
# Out:
#    GENDER            EDUCATION  MARITAL_STATUS
# 0       1  Среднее специальное  Состою в браке
# 1       1              Среднее  Состою в браке
# 2       1     Неполное среднее  Состою в браке
# 3       1               Высшее  Состою в браке
# 4       0              Среднее  Состою в браке

# %% [markdown]
# Если нам нужна первая или последняя строчка датафрейма, пользуемся конструкцией df[:1] или df[-1:]:

# %%
df[-1:]
# Out:
#        TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER EDUCATION  \
# 15222       0   37                  1                  0       0   Среднее
#
#        MARITAL_STATUS      ORG_TP_STATE                        JOB_DIR  \
# 15222  Состою в браке  Частная компания  Участие в основ. деятельности
#
#        PERSONAL_INCOME  OWN_AUTO  WORK_TIME  LOAN_MAX_DLQ_AMT
# 15222          20000.0         0       36.0               0.0

# %%
df[:1]
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
#
#              EDUCATION  MARITAL_STATUS      ORG_TP_STATE  \
# 0  Среднее специальное  Состою в браке  Частная компания
#
#                        JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0  Вспомогательный техперсонал           5000.0         0       18.0
#
#    LOAN_MAX_DLQ_AMT
# 0            1580.0

# %% [markdown]
# ## 2.8 Применение функций: apply, map и др.

# %% [markdown]
# #### Применение функции к каждому столбцу:

# %%
new_df = df.loc[:, 'PERSONAL_INCOME':'LOAN_MAX_DLQ_AMT']

# %%
new_df.apply(np.max, axis=0)
# Out:
# PERSONAL_INCOME      250000.0
# OWN_AUTO                  2.0
# WORK_TIME           2867959.0
# LOAN_MAX_DLQ_AMT      28012.2
# dtype: float64

# %% [markdown]
# Метод apply можно использовать и для того, чтобы применить функцию к каждой строке. Для этого нужно указать axis=1.

# %%
new_df.apply(np.max, axis=1)
# Out:
# 0          5000.0
# 1         12000.0
# 2          9000.0
# 3         25000.0
# 4         12000.0
# 5         12000.0
# 6         15000.0
# 7          6000.0
# 8        100000.0
# 9          7000.0
# 10        19000.0
# 11        18000.0
# 12         7000.0
# 13        12000.0
# 14        20000.0
# 15        60000.0
# 16        10000.0
# 17         5200.0
# 18        35000.0
# 19        15000.0
# 20        10000.0
# 21        10000.0
# 22        14000.0
# 23        10000.0
# 24         8000.0
# 25        13000.0
# 26        12500.0
# 27        12000.0
# 28        20000.0
# 29         5000.0
#            ...
# 15193     12000.0
# 15194     10000.0
# 15195     10000.0
# 15196      8000.0
# 15197     11000.0
# 15198      7000.0
# 15199     10000.0
# 15200      8000.0
# 15201     25000.0
# 15202     10000.0
# 15203     12000.0
# 15204      7000.0
# 15205     12000.0
# 15206     14500.0
# 15207     12000.0
# 15208      8000.0
# 15209      7000.0
# 15210     10000.0
# 15211     10000.0
# 15212     10000.0
# 15213     15000.0
# 15214      8100.0
# 15215      9500.0
# 15216     13000.0
# 15217     10000.0
# 15218     12000.0
# 15219     10000.0
# 15220      6000.0
# 15221      4500.0
# 15222     20000.0
# Length: 15223, dtype: float64

# %% [markdown]
# #### Применение функции к каждой ячейке столбца

# %% [markdown]
# Допустим, нас интересуют все люди - у которых их вид образования начинается с буквы В.
#
# В данному случае это можно сделать по-разному, но наибольшую свободу дает связка apply-lambda – применение функции ко всем значениям в столбце.

# %%
df[df['EDUCATION'].apply(lambda state: state[0] == 'В')].head()
# Out:
#     TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER EDUCATION  \
# 3        0   39                  1                  0       1    Высшее
# 6        0   35                  1                  0       0    Высшее
# 8        0   53                  1                  0       0    Высшее
# 14       0   38                  1                  0       1    Высшее
# 15       1   41                  1                  0       1    Высшее
#
#     MARITAL_STATUS                    ORG_TP_STATE  \
# 3   Состою в браке    Государственная комп./учреж.
# 6      Разведен(а)    Государственная комп./учреж.
# 8   Состою в браке                Частная компания
# 14  Состою в браке    Государственная комп./учреж.
# 15     Разведен(а)  Индивидуальный предприниматель
#
#                           JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 3   Участие в основ. деятельности          25000.0         0      168.0
# 6   Участие в основ. деятельности          15000.0         0        6.0
# 8   Участие в основ. деятельности         100000.0         0      156.0
# 14  Участие в основ. деятельности          20000.0         0      120.0
# 15  Участие в основ. деятельности          60000.0         0      168.0
#
#     LOAN_MAX_DLQ_AMT
# 3             1590.0
# 6                0.0
# 8                0.0
# 14               0.0
# 15               0.0

# %% [markdown]
# Для замены используют команду replace

# %%
df = df.replace({'Высшее': 'High'})
df.head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
# 1       0   32                  1                  0       1
# 2       0   52                  1                  0       1
# 3       0   39                  1                  0       1
# 4       0   30                  1                  0       0
#
#              EDUCATION  MARITAL_STATUS                    ORG_TP_STATE  \
# 0  Среднее специальное  Состою в браке                Частная компания
# 1              Среднее  Состою в браке  Индивидуальный предприниматель
# 2     Неполное среднее  Состою в браке    Государственная комп./учреж.
# 3                 High  Состою в браке    Государственная комп./учреж.
# 4              Среднее  Состою в браке    Государственная комп./учреж.
#
#                          JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0    Вспомогательный техперсонал           5000.0         0       18.0
# 1  Участие в основ. деятельности          12000.0         0       97.0
# 2  Участие в основ. деятельности           9000.0         0       84.0
# 3  Участие в основ. деятельности          25000.0         0      168.0
# 4  Участие в основ. деятельности          12000.0         0      101.0
#
#    LOAN_MAX_DLQ_AMT
# 0            1580.0
# 1            4020.0
# 2               0.0
# 3            1590.0
# 4            2230.0

# %% [markdown]
# #### Преобразование датафреймов

# %%
df['Долговая нагрузка'] = df['LOAN_MAX_DLQ_AMT'] / df['PERSONAL_INCOME']
df.head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
# 1       0   32                  1                  0       1
# 2       0   52                  1                  0       1
# 3       0   39                  1                  0       1
# 4       0   30                  1                  0       0
#
#              EDUCATION  MARITAL_STATUS                    ORG_TP_STATE  \
# 0  Среднее специальное  Состою в браке                Частная компания
# 1              Среднее  Состою в браке  Индивидуальный предприниматель
# 2     Неполное среднее  Состою в браке    Государственная комп./учреж.
# 3                 High  Состою в браке    Государственная комп./учреж.
# 4              Среднее  Состою в браке    Государственная комп./учреж.
#
#                          JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0    Вспомогательный техперсонал           5000.0         0       18.0
# 1  Участие в основ. деятельности          12000.0         0       97.0
# 2  Участие в основ. деятельности           9000.0         0       84.0
# 3  Участие в основ. деятельности          25000.0         0      168.0
# 4  Участие в основ. деятельности          12000.0         0      101.0
#
#    LOAN_MAX_DLQ_AMT  Долговая нагрузка
# 0            1580.0           0.316000
# 1            4020.0           0.335000
# 2               0.0           0.000000
# 3            1590.0           0.063600
# 4            2230.0           0.185833

# %% [markdown]
# Чтобы удалить столбцы или строки, воспользуйтесь методом drop, передавая в качестве аргумента нужные индексы и требуемое значение параметра axis (1, если удаляете столбцы, и ничего или 0, если удаляете строки):

# %%
# избавляемся от созданных только что столбцов
df = df.drop(['Долговая нагрузка'], axis=1) 


# а вот так можно удалить строчки
df.drop([1, 2]).head()
# Out:
#    TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0       0   49                  1                  0       1
# 3       0   39                  1                  0       1
# 4       0   30                  1                  0       0
# 5       0   29                  1                  0       0
# 6       0   35                  1                  0       0
#
#              EDUCATION    MARITAL_STATUS                  ORG_TP_STATE  \
# 0  Среднее специальное    Состою в браке              Частная компания
# 3                 High    Состою в браке  Государственная комп./учреж.
# 4              Среднее    Состою в браке  Государственная комп./учреж.
# 5              Среднее  Гражданский брак              Частная компания
# 6                 High       Разведен(а)  Государственная комп./учреж.
#
#                          JOB_DIR  PERSONAL_INCOME  OWN_AUTO  WORK_TIME  \
# 0    Вспомогательный техперсонал           5000.0         0       18.0
# 3  Участие в основ. деятельности          25000.0         0      168.0
# 4  Участие в основ. деятельности          12000.0         0      101.0
# 5      Адм-хоз. и трансп. службы          12000.0         1       40.0
# 6  Участие в основ. деятельности          15000.0         0        6.0
#
#    LOAN_MAX_DLQ_AMT
# 0            1580.0
# 3            1590.0
# 4            2230.0
# 5               0.0
# 6               0.0
